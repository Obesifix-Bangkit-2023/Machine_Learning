# %%
import os
import zipfile
import random
import shutil
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile
import matplotlib.pyplot as plt
import numpy as np

# %%
test_dir = r"D:\natasha\kuliah\sem 6\bangkit\coba python\project capstone\dataset\fix\test"
def train_val_generators(test_dir):
    test_datagen = ImageDataGenerator(rescale=1.0/255.)
    test_generator = test_datagen.flow_from_directory(directory=test_dir,
                                                                batch_size=16,
                                                                target_size=(256, 256))
    return test_generator
test_generator = train_val_generators(test_dir)
# Out:
# Found 950 images belonging to 19 classes.

# %%
load_train_model = tf.keras.models.load_model(r"D:\natasha\kuliah\sem 6\bangkit\coba python\project capstone\hasil model\2. mymodelhopefullyfinal.h5")
load_train_model.evaluate(test_generator)
# Out:
# 60/60 [==============================] - 116s 2s/step - loss: 0.4627 - accuracy: 0.8663
# [0.4626975953578949, 0.8663157820701599]

# %%
from keras.utils import load_img, img_to_array

def img_test(path):
  img = load_img(path, target_size=(256, 256))
  x = img_to_array(img)
  x = tf.expand_dims(x, axis=0)/255.
  classes = load_train_model.predict(x, batch_size=128).argmax(axis=1)
  print(path)
  return classes

# %%
test_file_name = os.listdir(test_dir)
test_file_name
# Out:
# ['apple',
#  'banana',
#  'chicken curry',
#  'chicken wings',
#  'donuts',
#  'french fries',
#  'fried chicken',
#  'fried rice',
#  'hamburger',
#  'hot dog',
#  'ice cream',
#  'omelette',
#  'onion rings',
#  'orange',
#  'pancakes',
#  'pizza',
#  'rice',
#  'spaghetti bolognese',
#  'sushi']

# %%
acc=[]
for count, name in enumerate(test_file_name):
   path = os.path.join(test_dir, name)
   print(f"Folder name : {path}")
   path_value = os.listdir(path)
   path_value.sort()
   false_acc = 0
   correct_acc = 0
   for i in path_value:
    file = os.path.join(path, i)
    img = load_img(file, target_size=(256, 256))
    x = img_to_array(img)
    x = tf.expand_dims(x, axis=0)/255.
    x = load_train_model.predict(x, batch_size=128).argmax(axis=1)
    pred = x[0]
    if pred != count:
      false_acc += 1
    else:
      correct_acc += 1
   print(f"There're {correct_acc} correct prediction from total of {len(path_value)} images.")
   print(f"Accuracy : {correct_acc/len(path_value)}")
   acc.append(correct_acc/len(path_value))
# Out:
# Folder name : D:\natasha\kuliah\sem 6\bangkit\coba python\project capstone\dataset\fix\test\apple
# ...
# 1/1 [==============================] - 0s 350ms/step
# There're 47 correct prediction from total of 50 images.
# Accuracy : 0.94
# Folder name : D:\natasha\kuliah\sem 6\bangkit\coba python\project capstone\dataset\fix\test\banana
# ...
# 1/1 [==============================] - 0s 220ms/step
# There're 45 correct prediction from total of 50 images.
# Accuracy : 0.9
# Folder name : D:\natasha\kuliah\sem 6\bangkit\coba python\project capstone\dataset\fix\test\chicken curry
# ...
# 1/1 [==============================] - 0s 219ms/step
# There're 36 correct prediction from total of 50 images.
# Accuracy : 0.72
# Folder name : D:\natasha\kuliah\sem 6\bangkit\coba python\project capstone\dataset\fix\test\chicken wings
# ...
# 1/1 [==============================] - 0s 362ms/step
# There're 43 correct prediction from total of 50 images.
# Accuracy : 0.86
# ...

# %%
print(img_test(r"D:\natasha\kuliah\sem 6\bangkit\coba python\project capstone\dataset\fix\test\apple\apple (154).jpg"))
# Out:
# 1/1 [==============================] - 0s 275ms/step
# D:\natasha\kuliah\sem 6\bangkit\coba python\project capstone\dataset\fix\test\apple\apple (154).jpg
# [0]

# %%
accuracy=np.sum(acc)/19
print(accuracy)
for count, name in enumerate(test_file_name):
    print(f"{name}: {acc[count]}")
# Out:
# 0.866315789473684
# apple: 0.94
# banana: 0.9
# chicken curry: 0.72
# chicken wings: 0.86
# donuts: 0.84
# french fries: 0.96
# fried chicken: 0.92
# fried rice: 0.92
# hamburger: 0.82
# hot dog: 0.82
# ice cream: 0.9
# omelette: 0.74
# onion rings: 0.88
# orange: 0.94
# pancakes: 0.74
# pizza: 0.88
# rice: 0.94
# spaghetti bolognese: 0.92
# sushi: 0.82
