# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.neighbors import NearestNeighbors

class Recommender:
    
    def __init__(self):
        self.data = pd.read_csv(r'/content/drive/MyDrive/capstone/recommendation system/new_recommendation_processedfinal.csv')
    
    def get_features(self):
        #getting dummies of dataset
        preference_dummies = self.data.FoodCategory.str.get_dummies()
        cal_dummies = self.data.cal_standart.str.get_dummies(sep=' ')
        fat_dummies = self.data.fat_standart.str.get_dummies(sep=' ')
        carb_dummies = self.data.carbo_standart.str.get_dummies(sep=' ')
        protein_dummies = self.data.protein_standart.str.get_dummies(sep=' ')
        feature_df = pd.concat([preference_dummies,cal_dummies,fat_dummies,carb_dummies,protein_dummies],axis=1)
        return feature_df
    def k_neighbor(self,inputs):
        feature_df = self.get_features()
        
        model = NearestNeighbors(n_neighbors=25, algorithm='ball_tree')
        
        # fitting model with dataset features
        model.fit(feature_df)
        
        df_results = pd.DataFrame(columns=list(self.data.columns))
        
      
        # getting distance and indices for k nearest neighbor
        distances , indices = model.kneighbors(inputs)

        for i in list(indices):
            df_results = df_results.append(self.data.loc[i])
                
        df_results = df_results.filter(['Name','Images', 'Calories', 'FatContent', 'CarbohydrateContent', 'ProteinContent','Keywords','FoodCategory'])
        df_results = df_results.drop_duplicates(subset=['Name'])
        df_results = df_results.reset_index(drop=True)
        return df_results

#create variable for filtering
ob = Recommender()
data = ob.get_features()
total_features = data.columns
d = dict()
for i in total_features:
    d[i]= 0
print(d)
print("what do you like?\n")

#input for preference and size
pref_input= input()
pref_inputtt = pref_input.split(", ")
print("\nsize:\n")
size_input=input()


#variable change for every preference
if size_input=='obese':
    d['low_cal']=1
    d['low_fat']=1
    d['low_carb']=1
    d['low_pro']=1
elif size_input=='overweight':
    d['so_so_cal']=1
    d['low_fat']=1
    d['low_carb']=1
    d['low_pro']=1
elif size_input=='normal':
    d['midhigh_cal']=1
    d['so_so_fat']=1
    d['so_carb']=1
    d['so_so_pro']=1
elif size_input=='underweight':
    d['high_cal']=1
    d['high_fat']=1
    d['high_carb']=1
    d['high_pro']=1
for i in pref_inputtt:
    d[i] = 1
final_input = list(d.values())
#print result
results = ob.k_neighbor([final_input]) 
results
# Out:
# {'Beef': 0, 'Bread': 0, 'Breakfast': 0, 'Chicken': 0, 'Cookies': 0, 'Dairy Product': 0, 'Dessert': 0, 'Duck': 0, 'Fish': 0, 'Fruit': 0, 'Lamb': 0, 'Low Cholestrol': 0, 'Lunch': 0, 'Pasta': 0, 'Pork': 0, 'Rice': 0, 'Seafood': 0, 'Soup': 0, 'Soy Product': 0, 'Vegetable': 0, 'high_cal': 0, 'low_cal': 0, 'midhigh_cal': 0, 'so_so_cal': 0, 'high_fat': 0, 'low_fat': 0, 'so_so_fat': 0, 'high_carb': 0, 'low_carb': 0, 'so_carb': 0, 'high_pro': 0, 'low_pro': 0, 'so_so_pro': 0}
# what do you like?
#
# Duck, Fish, Fruit, Bread, Beef
#
# size:
#
# underweight
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# <ipython-input-7-55e9952d37d4>:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(self.data.loc[i])
#                                                  Name  \
# 0                                 Peanut Butter Bread
# 1                             Best Ever Italian Bread
# 2    Pumpkin Wheat Multigrain Bread (Abm &amp; Vegan)
# 3                     Provencal Cheese and Herb Bread
# 4       Honey Whole Wheat Pecan Bread (Bread Machine)
# 5           Bonzai Burger (From Red Robin Restaurant)
# 6                                    Garden Herb Loaf
# 7                                        Quinoa Bread
# 8                        100% Whole Wheat Bread (Abm)
# 9                      Ballymaloe Brown Bread (Zwt-8)
# 10                                 Mom's Banana Bread
# 11                        Lemon Blueberry Crumb Bread
# 12                          Strawberry Banana Muffins
# 13             Banana Nut Bread for the Bread Machine
# 14                                    Corn Lightbread
# 15        Finnish Sweet Cardamom Raisin Bread (Pulla)
# 16                              Chocolate Marble Cake
# 17                          Green Onion Drop Biscuits
# 18                            Banana All Bran Muffins
# 19                            Classic Oatmeal Cookies
# 20                 The Garbage Plate (Burger Version)
# 21                      Instant Chocolate Pudding Mix
# 22               Peanut Butter Cookies Without Butter
# 23  Gouda Grilled Cheese With Tahini Black Bean Hu...
# 24             No Bake Cookies With a Measure of Love
#
#                                                Images  Calories  FatContent  \
# 0   "https://img.sndimg.com/food/image/upload/w_55...   2560.70        74.3
# 1   c("https://img.sndimg.com/food/image/upload/v1...   2615.80        33.9
# 2   "https://img.sndimg.com/food/image/upload/w_55...   2327.20        63.6
# 3   "https://img.sndimg.com/food/image/upload/w_55...   2311.00        74.1
# 4   "https://img.sndimg.com/food/image/upload/w_55...   2005.70        67.0
# 5   c("https://img.sndimg.com/food/image/upload/w_...   1120.80        34.1
# 6   c("https://img.sndimg.com/food/image/upload/w_...   2712.20        75.0
# 7   "https://img.sndimg.com/food/image/upload/w_55...   2772.70        89.2
# 8   c("https://img.sndimg.com/food/image/upload/w_...   2154.80        56.1
# 9   "https://img.sndimg.com/food/image/upload/w_55...   2151.50        17.2
# 10  "https://img.sndimg.com/food/image/upload/w_55...   3052.30       116.0
# 11  "https://img.sndimg.com/food/image/upload/w_55...   3170.70       105.2
# 12  c("https://img.sndimg.com/food/image/upload/w_...   2112.10        58.4
# 13  c("https://img.sndimg.com/food/image/upload/w_...   2493.30       121.9
# 14  "https://img.sndimg.com/food/image/upload/w_55...   2281.90        55.1
# 15  "https://img.sndimg.com/food/image/upload/w_55...   1195.95        41.2
# 16  c("https://img.sndimg.com/food/image/upload/w_...   2872.70        80.7
# 17  c("https://img.sndimg.com/food/image/upload/w_...   1721.10        78.2
# 18  c("https://img.sndimg.com/food/image/upload/w_...   2091.20        84.6
# 19  "https://img.sndimg.com/food/image/upload/w_55...   4701.50       221.8
# 20  c("https://img.sndimg.com/food/image/upload/w_...   3020.90       157.6
# 21  "https://img.sndimg.com/food/image/upload/w_55...   3194.90       206.1
# 22  "https://img.sndimg.com/food/image/upload/w_55...   4210.00       247.2
# 23  c("https://img.sndimg.com/food/image/upload/w_...   3082.30        84.9
# 24  "https://img.sndimg.com/food/image/upload/w_55...   3783.90       132.3
#
#     CarbohydrateContent  ProteinContent  \
# 0                 418.5           69.40
# 1                 494.8           72.20
# 2                 392.9           83.20
# 3                 325.4           79.50
# 4                 313.7           67.90
# 5                 124.1           74.20
# 6                 434.7           70.10
# 7                 412.1           81.00
# 8                 366.6           76.10
# 9                 448.5           90.70
# 10                472.4           42.40
# 11                525.1           43.60
# 12                368.7           36.10
# 13                319.8           38.10
# 14                406.4           48.90
# 15                186.0           23.05
# 16                495.9           56.20
# 17                214.3           39.90
# 18                319.8           50.40
# 19                624.7           65.10
# 20                281.5          148.80
# 21                329.9           58.20
# 22                435.8           94.60
# 23                452.0          119.50
# 24                605.4           71.80
#
#                                              Keywords FoodCategory
# 0   c("Breads", "Healthy", "Brunch", "< 60 Mins", ...        Bread
# 1   c("Breads", "European", "Low Cholesterol", "He...        Bread
# 2   c("Breads", "Pumpkin", "Vegetable", "Vegan", "...        Bread
# 3                            c("Breads", "< 4 Hours")        Bread
# 4                            c("Grains", "< 4 Hours")        Bread
# 5          c("Tropical Fruits", "Fruit", "< 30 Mins")        Fruit
# 6                   c("Healthy", "< 4 Hours", "Easy")        Bread
# 7          c("Grains", "Brunch", "< 15 Mins", "Easy")        Bread
# 8   c("Breads", "Bread Machine", "Beginner Cook", ...        Bread
# 9   c("Breads", "Grains", "European", "Weeknight",...        Bread
# 10  c("Breads", "Tropical Fruits", "Fruit", "< 4 H...        Bread
# 11                  c("Healthy", "< 4 Hours", "Easy")        Bread
# 12                c("Breads", "Healthy", "< 60 Mins")        Bread
# 13  c("Breads", "Canadian", "Savory", "Bread Machi...        Bread
# 14  c("Vegetable", "Low Cholesterol", "Healthy", "...        Bread
# 15  c("Breads", "Finnish", "Scandinavian", "Europe...        Bread
# 16                  c("Healthy", "< 4 Hours", "Easy")      Dessert
# 17                                        "< 30 Mins"        Bread
# 18  c("Breads", "Breakfast", "Grains", "Low Choles...        Bread
# 19  c("Dessert", "Cookie & Brownie", "< 60 Mins", ...      Cookies
# 20  c("Vegetable", "Meat", "< 4 Hours", "Inexpensi...    Vegetable
# 21                             c("< 15 Mins", "Easy")      Dessert
# 22         c("Cookie & Brownie", "< 30 Mins", "Easy")      Dessert
# 23                           c("Cheese", "< 60 Mins")        Lunch
# 24  c("Dessert", "Cookie & Brownie", "Potluck", "W...      Cookies
